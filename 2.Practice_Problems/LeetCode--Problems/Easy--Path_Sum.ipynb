# %% [markdown]
# ## Path Sum

# %% [markdown]
# ![image.png](attachment:9155b589-8abf-43af-9f6b-7b21d2f0dedb.png)

# %%
def dfs(node,curSum):
    if not node:
        return False 
    curSym += node.val
    if not node.left and not node.right and curSum -- targe
