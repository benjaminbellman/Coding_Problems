# %% [markdown]
# # Palindrome Linked List 2

# %% [markdown]
# Given the head of a singly linked list, return true if it is a palindrome or false otherwise.
#
#
# **Example 1:**
#
# Input: head = [1,2,2,1]
# Output: true
#
# **Example 2:**
#
# Input: head = [1,2]
# Output: false
#
# **Constraints:**
#
# - The number of nodes in the list is in the range [1, 105].
# - 0 <= Node.val <= 9

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def isPalindrome(self, head: Optional[ListNode]) -> bool:
        if not head or not head.next:
            return True

        # 1) Find middle (slow ends at middle for odd, start of 2nd half for even after adjustment)
        slow, fast = head, head
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next

        # If odd length, skip the middle node
        if fast:
            slow = slow.next

        # 2) Reverse second half
        prev = None
        curr = slow
        while curr:
            nxt = curr.next
            curr.next = prev
            prev = curr
            curr = nxt
        second = prev  # head of reversed second half

        # 3) Compare
        first = head
        while second:
            if first.val != second.val:
                return False
            first = first.next
            second = second.next

        return True
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6836/1980380473.py in <module>
#       5         self.next = next
#       6
# ----> 7 class Solution:
#       8     def isPalindrome(self, head: Optional[ListNode]) -> bool:
#       9         if not head or not head.next:
#
# ~\AppData\Local\Temp/ipykernel_6836/1980380473.py in Solution()
#       6
#       7 class Solution:
# ----> 8     def isPalindrome(self, head: Optional[ListNode]) -> bool:
#       9         if not head or not head.next:
#      10             return True
#
# NameError: name 'Optional' is not defined
